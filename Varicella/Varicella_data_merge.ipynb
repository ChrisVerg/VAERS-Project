# %%
import pandas as pd

# %% [markdown]
# # Import complete and clean dataset for VAERS

# %%
vaers  = pd.read_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS_CleanData/vaers_all.csv')
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_8772\2574172628.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   vaers  = pd.read_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS_CleanData/vaers_all.csv')

# %%
# Set notbook to allow for max rows
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
vaers.columns
# Out:
# Index(['Unnamed: 0', 'VAERS_ID', 'VAX_TYPE', 'VAX_MANU', 'VAX_LOT', 'VAX_NAME',
#        'AGE_YRS', 'STATE', 'SYMPTOM_TEXT', 'DIED', 'ER_VISIT', 'Year'],
#       dtype='object')

# %%
# View all the names of the different vaccines in the 'VAX_NAME' column

vaers.VAX_NAME.value_counts()
# Out:
# COVID19 (COVID19 (MODERNA))                                356439
# COVID19 (COVID19 (PFIZER-BIONTECH))                        335439
# VARICELLA (VARIVAX)                                         78448
# MEASLES + MUMPS + RUBELLA (MMR II)                          72272
# COVID19 (COVID19 (JANSSEN))                                 57571
# ZOSTER (SHINGRIX)                                           56208
# PNEUMO (PNEUMOVAX)                                          53767
# ZOSTER LIVE (ZOSTAVAX)                                      40902
# HPV (GARDASIL)                                              37121
# INFLUENZA (SEASONAL) (FLUZONE)                              36077
# PNEUMO (PREVNAR13)                                          28517
# HEP B (ENGERIX-B)                                           28115
# HEP B (RECOMBIVAX HB)                                       26212
# POLIO VIRUS, INACT. (IPOL)                                  24334
# ...

# %% [markdown]
# ## Based on the data looking at cumulative vaccine injuries since the beginning of VAERS in (year), excluding COVID, Varicella has the largest number of vaccine injuries recorded.
#
# * Because of this, I will examine the amout of cases, and vaccine history for this communiciable disease.

# %%
cases  = pd.read_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS_CleanData/Chicken_Pox_cases.csv')

# %%
cases
# Out:
#     Year Number of Reported Cases
# 0   1993                  117,119
# 1   1994                  154,429
# 2   1995                  150,976
# 3   1996                  125,165
# 4   1997                  103,408
# 5   1998                   81,892
# 6   1999                   56,130
# 7   2000                   27,786
# 8   2001                    9,417
# 9   2002                    6,821
# 10  2003                    5,384
# 11  2004                    5,248
# 12  2005                    4,492
# 13  2006                    3,194
# 14  2007                    3,786
# 15  2008                    3,453
# 16  2009                    3,364
# 17  2010                    3,082
# 18  2011                    6,573
# 19  2012                   11,279
# 20  2013                    9,246
# 21  2014                    7,786
# 22  2015                    8,766
# 23  2016                    7,830
# 24  2017                    6,380
# 25  2018                    5,275
# ...

# %%
varicella_merged = pd.merge(vaers, cases, on='Year')

# %%
varicella_merged.rename(columns=)
varicella_merged.columns
# Out:
# Index(['Unnamed: 0', 'VAERS_ID', 'VAX_TYPE', 'VAX_MANU', 'VAX_LOT', 'VAX_NAME',
#        'AGE_YRS', 'STATE', 'SYMPTOM_TEXT', 'DIED', 'ER_VISIT', 'Year',
#        'Number of Reported Cases'],
#       dtype='object')

# %%
varicella_merged[['Year','VAX_NAME', 'Number of Reported Cases']]

# %%
varicella_merged.to_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS_CleanData/varicella_merged.csv')
