# %%
import pandas as pd

# %% [markdown]
# # Use Python to process VAERS data

# %%
VAERSVAX1990 = pd.read_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS-data/1990VAERSVAX.csv')

# %%
symptoms = pd.read_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS-data/1990VAERSSYMPTOMS.csv')

# %%
otherinfo = pd.read_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS-data/1990VAERSDATA.csv')

# %%
pd.options.display.max_columns = None
display(otherinfo)
# Out:
#       VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0        25001  07/02/1990    WI      0.2      NaN      NaN   F      NaN
# 1        25003  07/02/1990    TX      0.8      NaN      NaN   M      NaN
# 2        25004  07/02/1990    NY      0.9      NaN      NaN   M      NaN
# 3        25005  07/02/1990    OK      NaN      NaN      NaN   U      NaN
# 4        25006  07/02/1990    OH     16.0     16.0      NaN   F      NaN
# ...        ...         ...   ...      ...      ...      ...  ..      ...
# 2097     27269  12/31/1990    OK      1.8      NaN      NaN   M      NaN
# 2098     27270  12/31/1990    NY      5.0      NaN      NaN   M      NaN
# 2099     27271  12/31/1990    IL      0.2      NaN      NaN   U      NaN
# 2100     27272  12/31/1990    TX      1.5      NaN      NaN   F      NaN
# 2101     27273  12/31/1990    CA      0.3      NaN      NaN   M      NaN
#
#                                            SYMPTOM_TEXT DIED DATEDIED  \
# ...

# %% [markdown]
# # Based on the data, I selected the columns that should be useful in answer the question posed.

# %%
vax = VAERSVAX1990[['VAERS_ID', 'VAX_TYPE', 'VAX_MANU', 'VAX_LOT', 'VAX_NAME']]

# %%
data = otherinfo[['VAERS_ID', 'AGE_YRS', 'STATE', 'SYMPTOM_TEXT', 'DIED', 'ER_VISIT']]

# %% [markdown]
# # Merge the data sets on VAERS_ID

# %%
vaers1990 = pd.merge(vax, data, on= 'VAERS_ID')

# %% [markdown]
# # Add column with year (1990)

# %%
vaers1990['Year'] = 1990

# %%
vaers1990.to_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS-data/1990/vaers1990.csv')

# %% [markdown]
# # 1991: Below I imported the two CSV files for 1991

# %%
vaersdata = pd.read_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS-data/1991/1991VAERSDATA.csv')

# %%
vaersvax = pd.read_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS-data/1991/1991VAERSVAX.csv')

# %% [markdown]
# # Select the columns with potentially useful information

# %%
vax91 = vaersvax[['VAERS_ID', 'VAX_TYPE', 'VAX_MANU', 'VAX_LOT', 'VAX_NAME']]

# %%
data91 = otherinfo[['VAERS_ID', 'AGE_YRS', 'STATE', 'SYMPTOM_TEXT', 'DIED', 'ER_VISIT']]

# %% [markdown]
# # Merges the datasets and add the "Year" column
# ##  Save the 1991 data as CSV

# %%
vaers1991 = pd.merge(vax, data, on= 'VAERS_ID')

# %%
vaers1991['Year'] = 1991

# %%
vaers1991.to_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS-data/1991/vaers1991.csv')

# %% [markdown]
# # Combine the cleaned 1990 and 1991 data

# %%
vaers90_91 = pd.concat([vaers1990, vaers1991])

# %%
vaers90_91.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5574 entries, 0 to 2786
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   VAERS_ID      5574 non-null   int64
#  1   VAX_TYPE      5574 non-null   object
#  2   VAX_MANU      5574 non-null   object
#  3   VAX_LOT       4512 non-null   object
#  4   VAX_NAME      5574 non-null   object
#  5   AGE_YRS       5032 non-null   float64
#  6   STATE         5502 non-null   object
#  7   SYMPTOM_TEXT  5560 non-null   object
#  8   DIED          270 non-null    object
#  9   ER_VISIT      1080 non-null   object
#  10  Year          5574 non-null   int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 522.6+ KB
