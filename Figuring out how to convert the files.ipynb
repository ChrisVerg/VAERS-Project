# %%
import pandas as pd

# %%
vaersdata97 = pd.read_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS-data/VAERS_Messy/1997VAERSDATA.csv', encoding = 'cp1252')

# %%
vaersdata97.head()
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX    RPT_DATE  \
# 0     93502  01/02/1997    MN     32.0     32.0      NaN   F  12/13/1996
# 1     93508  01/02/1997    ID      0.2      0.0      0.2   M  11/08/1996
# 2     93509  01/02/1997    ID      0.6      0.0      0.6   F  11/26/1996
# 3     93510  01/02/1997    ID      1.3      1.0      0.3   M  12/05/1996
# 4     93511  01/02/1997    ID      0.7      0.0      0.7   F  12/06/1996
#
#                                         SYMPTOM_TEXT DIED  ... CUR_ILL  \
# 0  pt exp numbness, weakness, bilateral bells pal...  NaN  ...    none
# 1  pt recv vax; was very fussy and unconsolable, ...  NaN  ...    none
# 2  pt recv vax; had fever; crying almost continuo...  NaN  ...    none
# 3  pt recv vax; fever of 103 w/in hr p/ vax lasti...  NaN  ...    none
# 4  pt recv vax; T of 103; fever; screaming all ni...  NaN  ...    none
#
#   HISTORY              PRIOR_VAX SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT  \
# ...

# %%
vaersdata97.to_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS-data/VAERS_Clean/1997testVAERSDATA.csv', encoding = 'utf-8')

# %%
test_vaers = pd.read_csv('C:/Users/chris/Desktop/WozU_Data_Science/VAERS-data/VAERS_Clean/1997testVAERSDATA.csv')

# %%
test_vaers.head()
# Out:
#    Unnamed: 0  VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX  \
# 0           0     93502  01/02/1997    MN     32.0     32.0      NaN   F
# 1           1     93508  01/02/1997    ID      0.2      0.0      0.2   M
# 2           2     93509  01/02/1997    ID      0.6      0.0      0.6   F
# 3           3     93510  01/02/1997    ID      1.3      1.0      0.3   M
# 4           4     93511  01/02/1997    ID      0.7      0.0      0.7   F
#
#      RPT_DATE                                       SYMPTOM_TEXT  ... CUR_ILL  \
# 0  12/13/1996  pt exp numbness, weakness, bilateral bells pal...  ...    none
# 1  11/08/1996  pt recv vax; was very fussy and unconsolable, ...  ...    none
# 2  11/26/1996  pt recv vax; had fever; crying almost continuo...  ...    none
# 3  12/05/1996  pt recv vax; fever of 103 w/in hr p/ vax lasti...  ...    none
# 4  12/06/1996  pt recv vax; T of 103; fever; screaming all ni...  ...    none
#
# ...
